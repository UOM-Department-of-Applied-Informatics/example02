# %% [markdown]
# ### Συμπληρώστε την ημιτελή λύση της παρακάτω άσκησης στο επόμενο code block.
#
# Το πρόγραμμα πρέπει να διαβάζει δύο ακέραιους αριθμούς από το πληκτρολόγιο, όπου ο πρώτος είναι το κάτω όριο και ο δεύτερος το άνω όριο. Σε περίπτωση που ο δεύτερος αριθμός είναι μικρότερος από τον πρώτο, τους αντιμεταθέτει. Στη συνέχεια υπολογίζει όλους τους πρώτους αριθμούς μέσα σε αυτό το διάστημα. Για παράδειγμα αν ο χρήστης πληκτρολογήσει το 10 και το 27 τότε το πρόγραμμα εκτυπώνει όλους τους πρώτους αριθμούς μέσα στο διάστημα από 10 έως και 27.
#
# Ένας αριθμός ονομάζεται πρώτος αν διαιρείται ακριβώς μόνο με τον εαυτό του και με τη μονάδα. Για παράδειγμα οι αριθμοί 5, 7, 13, 17 είναι πρώτοι αριθμοί.

# %%
# Πρόγραμμα εκτύπωσης πρώτων αριθμών μεταξύ δύο αριθμών

low = int(input('Δώστε έναν ακέραιο αριθμό ως κάτω όριο: '))
high = int(input('Δώστε έναν ακέραιο αριθμό ως άνω όριο: '))

if high < low:
  low, high = high, low

print("Οι πρώτοι αριθμοί μεταξύ", low, "και", high, "είναι:")

for num in range( # Συμπληρώστε την range με τις κατάλληλες παραμέτρους
    if num > 1:
        for i in range( # Συμπληρώστε την range με τις κατάλληλες παραμέτρους
            if (num % i) == 0:
                break
        else:
            print(num, end=', ')

# %% [markdown]
# ### Συμπληρώστε την ημιτελή λύση της παρακάτω άσκησης στο επόμενο code block.
# Ένα ακρωνύμιο σχηματίζεται από μια φράση παίρνοντας το πρώτο γράμμα από κάθε λέξη που αυτή περιέχει. Για παράδειγμα το ακρωνύμιο ESA προκύπτει από τη φράση european space agency. Το πρόγραμμα ζητά από το χρήση να δώσει μια φράση και από αυτή δημιουργεί το ακρωνύμιο. Προσοχή, τα ακρωνύμια απαρτίζονται από κεφαλαία και μόνο γράμματα.
# Χρησιμοποιήστε τη μέθοδο split για να επεξεργαστείτε τη φράση. Περισσότερα θα βρείτε στο
# http://docs.python.org/3.13/library/stdtypes.html#str.split

# %%
sentence = input('Δώστε τη φράση: ')
listOfWords = # Συμπληρώστε την εντολή για τον διαχωρισμό των λέξεων

for word in listOfWords:
    # Συμπληρώστε τον κώδικα για την εμφάνιση του ακρωνυμίου

# %% [markdown]
# ### Συμπληρώστε την ημιτελή λύση της παρακάτω άσκησης στο επόμενο code block.
# Η Python παρέχει μια ενσωματωμένη συνάρτηση που ονομάζεται len η οποία επιστρέφει το μήκος μιας συμβολοσειράς. Η τιμή του len('allen') είναι 5. Γράψτε μια συνάρτηση με το όνομα right_justify που παίρνει ως παράμετρο μια συμβολοσειρά με το όνομα s και εκτυπώνει τη συμβολοσειρά με αρκετά κενά στα αριστερά, έτσι ώστε το τελευταίο γράμμα της συμβολοσειράς να βρίσκεται στη στήλη 70 της οθόνης.

# %%
def right_justify(s):
    # Συμπληρώστε τον κώδικα για την εμφάνιση της φράσης s με δεξιά στοίχιση
    
right_justify("Hello, World!")
right_justify("Python is fun!")
right_justify("I love programming!")

# %% [markdown]
# ### Χρήση Συναρτήσεων ως Αντικειμένων στην Python
#
# Ένα αντικείμενο συνάρτησης αποτελεί μια τιμή που μπορείτε να αναθέσετε σε μια μεταβλητή ή να περάσετε ως όρισμα. Για παράδειγμα, η `do_twice` είναι μια συνάρτηση που παίρνει ως όρισμα ένα αντικείμενο συνάρτησης και καλεί αυτό το όρισμα δύο φορές:
#
# ```python
# def do_twice(f):
#     f()
#     f()
# ```
#
# Ακολουθεί ένα παράδειγμα που χρησιμοποιεί τη συνάρτηση `do_twice` για να καλέσει δύο φορές μια συνάρτηση με όνομα `print_spam`:
#
# ```python
# def print_spam():
#     print("spam")
#
# do_twice(print_spam)
# ```
#
# **Ασκήσεις**
#
# 1. **Πληκτρολογήστε** αυτό το παράδειγμα και δοκιμάστε το.
# 2. **Τροποποιήστε** τη `do_twice` έτσι ώστε να παίρνει δύο ορίσματα: μία συνάρτηση και μια τιμή. Όταν εκτελείται, να καλεί τη συνάρτηση δύο φορές, περνώντας την τιμή ως όρισμα.
# 3. **Γράψτε** μια πιο γενική έκδοση του `print_spam`, που ονομάζεται `print_twice`, η οποία παίρνει ως όρισμα μια συμβολοσειρά και την εκτυπώνει δύο φορές.
# 4. **Χρησιμοποιήστε** την τροποποιημένη έκδοση του `do_twice` (του ζητήματος 2) για να καλέσετε την `print_twice` δύο φορές, δίνοντας ως όρισμα τη συμβολοσειρά `"spam"`.
# 5. **Ορίστε** μια νέα συνάρτηση που ονομάζεται `do_four`, η οποία παίρνει ως ορίσματα μία συνάρτηση και μια τιμή. Καλεί τη συνάρτηση τέσσερις φορές, περνώντας την τιμή ως παράμετρο. *Θα πρέπει να υπάρχουν μόνο δύο εντολές στο σώμα αυτής της συνάρτησης, όχι τέσσερις*.
# ```

# %%
# Άσκηση 1
def do_twice(f):
    # Συμπληρώστε τον δοσμένο κώδικα και δοκιμάστε τον

# %%
# Ασκήσεις 2 - 5

def do_twice(func, arg):
    """Runs a function twice.

    func: function object
    arg: argument passed to the function
    """
    # Συμπληρώστε τον κώδικα για την εκτέλεση της func με όρισμα το arg δύο φορές


def print_twice(arg):
    """Prints the argument twice.

    arg: anything printable
    """
    # Συμπληρώστε τον κώδικα για την εκτέλεση της print με όρισμα το arg δύο φορές


def do_four(func, arg):
    """Runs a function four times.

    func: function object
    arg: argument passed to the function
    """
    # Συμπληρώστε τον κώδικα για την εκτέλεση της func με όρισμα το arg τέσσερις φορές

do_twice(print, 'spam')
print()

do_four(print, 'spam')

# Θα πρέπει να εμφανιστεί:
# spam
# spam

# spam
# spam
# spam
# spam

# %% [markdown]
# ### Αναδρομικές κλήσεις - Συνάρτηση Ackermann
# Η συνάρτηση Ackermann \[A(m, n)\] ορίζεται ως εξής:
#
# $$A(m, n) =
# \begin{cases}
# n + 1, & \text{if } m = 0 \\
# A(m - 1, 1), & \text{if } m > 0 \text{ and } n = 0 \\
# A(m - 1, A(m, n - 1)), & \text{if } m > 0 \text{ and } n > 0.
# \end{cases}$$
#
# Δείτε https://en.wikipedia.org/wiki/Ackermann_function.
#
# Γράψτε μια συνάρτηση με το όνομα `ack` που υπολογίζει τη συνάρτηση του Ackermann. Χρησιμοποιήστε τη συνάρτησή σας για να υπολογίσετε το `ack(3, 4)`, το οποίο θα πρέπει να είναι **125**.
# Τι συμβαίνει για μεγαλύτερες τιμές των m και n;

# %%
def ack(m, n):
    """
    Computes the Ackermann function A(m, n)
    n, m: non-negative integers
    """
    # Συμπληρώστε τον κώδικα για τον υπολογισμό της συνάρτησης Ackermann


print(ack(3, 4))
